# %% [markdown]
# <a href="https://colab.research.google.com/github/Antoine-Salwan/Antoine-Salwan/blob/main/essay_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import files

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b05a7777-4aed-4f4e-9aeb-55facbd4e57d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b05a7777-4aed-4f4e-9aeb-55facbd4e57d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
pip install nltk

# %%
pip install spacy

# %%
import spacy

# %%
import ssl

# %%
import nltk

# %%
pip install scikit-learn

# %%
import sklearn

# %%
# !python -m spacy download en_core_web_sm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 67.3 MB/s eta 0:00:00
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
from nltk.tokenize import word_tokenize, sent_tokenize

# %%
df = pd.read_csv('CSV essay dataset.csv', encoding='latin1')

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f0983553-a398-459a-82bf-e1d0b4a696aa" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f0983553-a398-459a-82bf-e1d0b4a696aa">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('CSV essay dataset 2.csv', encoding='latin1')

# %%
from nltk.tokenize import word_tokenize, sent_tokenize

# %%
def tokenize_text(essay_text):
    return word_tokenize(essay_text)

# %%
def tokenize_text(prompt):
    return word_tokenize(prompt)

# %%
def tokenize_text(essay_text):
    return sentence_tokenize(essay_text)

# %%
def tokenize_text(essay_text):
    return sentence_tokenize(prompt)

# %%
nlp = spacy.load("en_core_web_sm")

# %%
df.head(10)
# Out:
#    Essay_ID     Essay_type                                         Essay_Text  \
# 0         1  Argumentative  Title: The E-Books and Paper Books \n Essay: ...
# 1         2  Argumentative  Title: Why We Lie Essay: Truly good people are...
# 2         3  Argumentative  Title: E-Books Friendly Suggestions \n Essay:...
# 3         4  Argumentative  Title: Books Vs. e-books \n Essay: \n   Metho...
# 4         5  Argumentative  Title: Paper Books should not be replaced /n ...
# 5         6  Argumentative  Title: e- books replacing paper books? \n Ess...
# 6         7  Argumentative  Title: What Do You Prefer? \n Essay: \n   Tod...
# 7         8  Argumentative  Title: Books or E-books? \n Essay: \n Collect...
# 8         9  Argumentative  Title: E-books instead of paper books \n Essa...
# 9        10  Argumentative  Title: importance of ebook \n Essay: \n      ...
#
#                                              Prompt  Numerical_score  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6601 entries, 0 to 6600
# Data columns (total 14 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Essay_ID                    6601 non-null   int64
#  1   Essay_type                  66 non-null     object
#  2   Essay_Text                  66 non-null     object
#  3   Prompt                      66 non-null     object
#  4   Numerical_score             66 non-null     float64
#  5   introduction_&claim_ score  66 non-null     float64
#  6   Topic_sentence              66 non-null     float64
#  7   Support                     66 non-null     float64
#  8   counter_argument            66 non-null     float64
#  9   refutation_&Evidence        66 non-null     float64
#  10  in-text_citation            66 non-null     float64
#  11  Unity_&_coherence           66 non-null     float64
#  12  Grammar_&_mechanics         66 non-null     float64
# ...

# %%
df1 = pd.read_csv('CSV essay dataset.csv', encoding='latin1')

# %%
df2 = pd.read_csv('CSV essay dataset 2.csv', encoding='latin1')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6601 entries, 0 to 6600
# Data columns (total 14 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Essay_ID                    6601 non-null   int64
#  1   Essay_type                  66 non-null     object
#  2   Essay_Text                  66 non-null     object
#  3   Prompt                      66 non-null     object
#  4   Numerical_score             66 non-null     float64
#  5   introduction_&claim_ score  66 non-null     float64
#  6   Topic_sentence              66 non-null     float64
#  7   Support                     66 non-null     float64
#  8   counter_argument            66 non-null     float64
#  9   refutation_&Evidence        66 non-null     float64
#  10  in-text_citation            66 non-null     float64
#  11  Unity_&_coherence           66 non-null     float64
#  12  Grammar_&_mechanics         66 non-null     float64
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6601 entries, 0 to 6600
# Data columns (total 14 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Essay_ID                    6601 non-null   int64
#  1   Essay_type                  66 non-null     object
#  2   Essay_Text                  66 non-null     object
#  3   Prompt                      66 non-null     object
#  4   Numerical_score             66 non-null     float64
#  5   introduction_&claim_ score  66 non-null     float64
#  6   Topic_sentence              66 non-null     float64
#  7   Support                     66 non-null     float64
#  8   counter_argument            66 non-null     float64
#  9   refutation_&Evidence        66 non-null     float64
#  10  in-text_citation            66 non-null     float64
#  11  Unity_&_coherence           66 non-null     float64
#  12  Grammar_&_mechanics         66 non-null     float64
# ...
